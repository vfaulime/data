# %%
# Notebook Title

# %%
## Introduction

This notebook is designed to show a series of practical exercises about data science. Throughout this notebook, we will explore various concepts and tools used in data analysis.

# %%
## Programming Languages ​​in Data Science

Below are some of the most commonly used programming languages ​​in data science:

1 - Python: An open-source programming language with a simple syntax, powerful libraries, and a large community.

2 - R: A highly specialized and precise language for statistical analysis and data visualization.

3 - SQL: A very popular and standardized language for database management.

# %%
## Data Science Libraries

Some of the most widely used libraries in data science are:

- Pandas: For data manipulation, structuring, and analysis.

- Seaborn: For creating statistical visualizations.

- NumPy: For numerical manipulation and calculations.

- Matplotlib: For creating static graphs and visualizations.

- Keras: For creating neural networks.

- TensorFlow / PyTorch: Libraries for deep learning.

# %%
## Data Science Tools

| Tools | Description |

|-----------------|-----------------------------------------------------------|

| Jupyter         | An interactive tool for creating notebooks with code and text. |

| Google Colab    | An online environment with access to Google Cloud resources. |

| Tableau         | Data visualization software. |

| Power BI        | A data visualization and business analytics tool from Microsoft. |

| GitHub          | A platform for version control and project collaboration. |

| Docker          | A tool for creating, deploying, and running containerized applications. |

# %%
## Examples of Arithmetic Expressions

Here are some examples of arithmetic operations in Python:

- **Addition**: `1 + 2`
- **Subtraction**: `10 - 1`
- **Multiplication**: `8 * 2`
- **Division**: `20/ 2`
- **Exponentiation**: `5 ** 2` (2 raised to the power of 3)

# %%
# Multiplying and adding two numbers
a = 2
b = 5
c = 10

# Multiplication
multiplication = (a * b)*c

# Addition
addition = c + a

multiplication, addition

# %%
# Convert minutes to hours
mnts = 150
hs = mnts / 60

hours

# %%
# Objectives of the notebook
objectives = [
    "Increase my knowledge of data science.",
    "Practice Python.",
    "Expand my knowledge of languages and tools."
]

objectives

# %%
## Author

Notebook created by Vanesa Faulime.
